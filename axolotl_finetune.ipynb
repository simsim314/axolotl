# %%
# !git clone https://github.com/simsim314/axolotl
# %cd axolotl
# !pip install -e .
# !pip install -U git+https://github.com/huggingface/peft.git
# !pip install deepspeed scipy
# !pip install flash-attn

# %%
# !wget  https://huggingface.co/datasets/simsim314/Hebrew_Noam30B_Tokenized/resolve/main/he_db.json

# %%
# !accelerate launch scripts/finetune.py examples/llama-2/qlora.yml

# %%
# !accelerate launch scripts/finetune.py examples/llama-2/qlora.yml --inference --lora_model_dir="./qlora-out"
